# %%
# 3.1 How many seconds are there in an hour?*
answer = 60 * 60
print("there are", answer, "seconds in an hour")
# Out:
# there are 3600 seconds in an hour

# %%
# 3.2 assign result to a cariable called seconds_per_hour.
seconds_per_hour = 60 * 60
print("there are", seconds_per_hour, "seconds in an hour")
# Out:
# there are 3600 seconds in an hour

# %%
# 3.3/3.4 how many seconds are in a day?
seconds_per_hour = 60 * 60
print("there are", seconds_per_hour, "seconds in an hour")
seconds_per_day = seconds_per_hour * 24
print("there are", seconds_per_day, "seconds in a day")
# Out:
# there are 3600 seconds in an hour
# there are 86400 seconds in a day

# %%
# 3.5 Divide seconds_per_day by seconds_per_hour. Use floating-point (/) division.
answerone = seconds_per_day / seconds_per_hour
print(answerone)
# Out:
# 24.0

# %%
#3.6 Divide seconds_per_day by seconds_per_hour, using integer (//) division. Did this number agree with the floating-point value from the previous question, aside from the final .0?
answertwo = seconds_per_day // seconds_per_hour
print(answertwo)
print("yes")
# Out:
# 24
# yes
