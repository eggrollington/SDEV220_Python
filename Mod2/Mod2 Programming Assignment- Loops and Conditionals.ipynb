# %%
#4.1
secret = 7
guess = int(input("guess a number between 1 and 10"))
if guess == secret:
    print("just right!")
elif guess > secret:
    print("too high")
else:
    print("too low")
# Out:
# guess a number between 1 and 10 7
# just right!

# %%
#4.2
small = True
green = False

if small and green == True:
    print("a pea is small and green")
elif small == False and green == True:
    print("A watermelon is not small but is green")
elif small is False and green is False:
    print("A pumpkin is not small or green")
elif small is True and green is False:
    print("A cherry is small and not green")
# Out:
# A cherry is small and not green

# %%
#6.1
values = [3, 2, 1, 0]
for i in values:
    print(i)
# Out:
# 3
# 2
# 1
# 0

# %%
#6.2
guess_me = 7
number = 0 
while number != guess_me:
    number = int(input("please input a number"))
    if number < guess_me:
        print("too low")
    elif number > guess_me:
        print("too high")
    else:
        print("just right")
# Out:
# please input a number 1
# too low
# please input a number 10
# too high
# please input a number 9
# too high
# please input a number 2
# too low
# please input a number 4
# too low
# please input a number 8
# too high
# please input a number 7
# just right

# %%
#6.3
guess_me = 5
for number in range(10):
    if number < guess_me:
        print("too low")
    elif number == guess_me:
        print("found it!")
        break
    elif number > guess_me:
        print("oops")
        break
# Out:
# too low
# too low
# too low
# too low
# too low
# found it!
