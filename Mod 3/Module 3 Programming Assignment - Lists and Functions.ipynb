# %%
#7.4 Make a list called things with these three strings as elements: "mozzarella", "cinderella", "salmonella".
things = ["mozzarella", "cinderella", "salmonella"]
print(things)
# Out:
# ['mozzarella', 'cinderella', 'salmonella']

# %%
#7.5 Capitalize the element in things that refers to a person and then print the list. Did it change the element in the list?
things[1] = "Cinderella"
print(things)
# Out:
# ['mozzarella', 'Cinderella', 'salmonella']

# %%
#7.6 Make the cheesy element of things all uppercase and then print the list.
things [0:1] = ["MOZZARELLA"] 
print(things)
# Out:
# ['MOZZARELLA', 'Cinderella', 'salmonella']

# %%
#7.7 Delete the disease element from things, collect your Nobel Prize, and print the list.
del things [2]
NobelPrizeCollected = True
print (things)
if NobelPrizeCollected == True:
    print ("Nobel Prize was been collected!")
# Out:
# ['MOZZARELLA', 'Cinderella']
# Nobel Prize was been collected!

# %%
#9.1 Define a function called good() that returns the following list: ['Harry', 'Ron', 'Hermione'].

def good():
    wizard = ['Harry', 'Ron', 'Hermione']
    print (wizard)
    return
good()
# Out:
# ['Harry', 'Ron', 'Hermione']

# %%
#9.2 Define a generator function called get_odds() that returns the odd numbers from range(10). Use a for loop to find and print the third value returned.
def get_odds():
    for number in range(10):
        if number % 2 == 1:
            yield number
count = 0
for number in get_odds():
    count += 1
    if count == 3:
        print ("The third number is: ", number)
# Out:
# The third number is:  5
